# %%
import pandas as pd
import requests
import numpy as np
import time
import re

# load Excel and clean contaminants
df = pd.read_excel("1. 95p_Original_35277_LFQ_PD_WT_vs_Ts65Dn_P14.xlsx")
df = df[~df['Accession'].str.startswith("Cont_")]
ratio_col = "Abundance Ratio: (Ts65Dn P14) / (WT P14)"

# utility functions
def clean_description(desc):
    return re.sub(r'\[.*?\]', '', desc).strip()
# species_prefix="mmu" for mouse
def get_kegg_gene_id(gene_symbol, species_prefix="mmu"):
    url = f"http://rest.kegg.jp/find/genes/{gene_symbol}"
    r = requests.get(url)
    if r.status_code != 200 or not r.text.strip():
        return None
    gene_symbol_lower = gene_symbol.lower()
    for line in r.text.strip().splitlines():
        if line.startswith(f"{species_prefix}:"):
            parts = line.split("\t")
            if len(parts) < 2:
                continue
            gene_id = parts[0]
            names = parts[1].lower().replace(";", ",").split(",")
            names = [n.strip() for n in names]
            if gene_symbol_lower in names:
                return gene_id
    return None
def get_kegg_pathway_ids(kegg_gene_id):
    url = f"http://rest.kegg.jp/link/pathway/{kegg_gene_id}"
    r = requests.get(url)
    if r.status_code != 200 or not r.text.strip():
        return []
    return [line.split("\t")[1].replace("path:", "")
            for line in r.text.strip().splitlines()]
def get_kegg_pathway_names(pathway_ids):
    names = []
    for pid in pathway_ids:
        url = f"http://rest.kegg.jp/get/{pid}"
        r = requests.get(url)
        if r.status_code == 200:
            for line in r.text.splitlines():
                if line.startswith("NAME"):
                    names.append(line.replace("NAME", "").strip())
                    break
        time.sleep(0.15)
    return names
def compute_hit_score(ratio):
    if pd.isna(ratio):
        return np.nan, None
    if ratio == 0:
        return 10, "Normal-only"
    if ratio == 1:
        return 0, "No-change"
    L = abs(np.log2(ratio))
    L = min(L, 10)
    return L, ("Up" if ratio > 1 else "Down")
# uniprot organism ID → 10090 (mouse)
def get_gene_symbol_uniprot(protein_name):
    query = protein_name + " AND organism:10090"
    url = f"https://www.uniprot.org/uniprotkb/search?query={query}&format=tsv&fields=genes"
    try:
        r = requests.get(url)
        if r.status_code == 200 and r.text.strip():
            lines = r.text.strip().splitlines()
            if len(lines) > 1:
                return lines[1].split()[0]
    except:
        pass
    return None

# containers for results
pathway_scores = {}
pathway_members = {}
hit_scores = []
updown_categories = []
protein_pathways = []

# main loop
for idx, row in df.iterrows():
    protein_name = clean_description(row["Description"])
    ratio = row[ratio_col]
    gene_symbol_full = row["Gene Symbol"] if not pd.isna(row["Gene Symbol"]) else ""
    gene_symbol = gene_symbol_full.split(";")[0].strip() if gene_symbol_full else get_gene_symbol_uniprot(protein_name)
    if not gene_symbol:
        print(f"{protein_name}: No gene symbol found")
        hit_scores.append(np.nan)
        updown_categories.append(None)
        protein_pathways.append("")
        continue
    # explicitly using mouse KEGG
    kegg_gene_id = get_kegg_gene_id(gene_symbol, species_prefix="mmu")
    if not kegg_gene_id:
        print(f"{protein_name} ({gene_symbol}): No KEGG gene ID found")
        hit_scores.append(np.nan)
        updown_categories.append(None)
        protein_pathways.append("")
        continue
    pathway_ids = get_kegg_pathway_ids(kegg_gene_id)
    if not pathway_ids:
        print(f"{protein_name} ({gene_symbol}, {kegg_gene_id}): No pathways found")
        hit_scores.append(np.nan)
        updown_categories.append(None)
        protein_pathways.append("")
        continue
    pathway_names = get_kegg_pathway_names(pathway_ids)
    protein_pathways.append("; ".join(pathway_names))
    hit_score, category = compute_hit_score(ratio)
    hit_scores.append(hit_score)
    updown_categories.append(category)
    for pid, pname in zip(pathway_ids, pathway_names):
        if pid not in pathway_scores:
            pathway_scores[pid] = {"name": pname, "total_score": 0, "protein_count": 0}
        pathway_scores[pid]["total_score"] += hit_score
        pathway_scores[pid]["protein_count"] += 1
        if pid not in pathway_members:
            pathway_members[pid] = []
        pathway_members[pid].append(protein_name)
    time.sleep(0.3)
    
# save outputs
df["Hit Score"] = hit_scores
df["Up/Down Category"] = updown_categories
df["Pathways"] = protein_pathways
pw_summary = pd.DataFrame([
    {
        "Pathway ID": pid,
        "Pathway Name": info["name"],
        "Total Hit Score": info["total_score"],
        "Protein Count": info["protein_count"]
    }
    for pid, info in pathway_scores.items()
]).sort_values("Total Hit Score", ascending=False)
pw_members_df = pd.DataFrame([
    {"Pathway ID": pid, "Pathway Name": pathway_scores[pid]["name"], "Proteins": "; ".join(prots)}
    for pid, prots in pathway_members.items()
])
output_filename = "2. 95p_Original_35277_LFQ_PD_WT_vs_Ts65Dn_P14.xlsx"
with pd.ExcelWriter(output_filename, engine="openpyxl") as writer:
    df.to_excel(writer, sheet_name="Protein Data P14", index=False)
    pw_summary.to_excel(writer, sheet_name="Pathway Summary P14", index=False)
    pw_members_df.to_excel(writer, sheet_name="Pathway Members P14", index=False)
print(f"\nSaved full mouse analysis to {output_filename}!")
# Out:
# Nuclear ubiquitous casein and cyclin-dependent kinase substrate 1 (Nucks1, mmu:98415): No pathways found
# Uncharacterized protein FLJ45252 homolog: No gene symbol found
# Serine protease inhibitor A3K (Serpina3k, mmu:20714): No pathways found
# Malectin (Mlec, mmu:109154): No pathways found
# RNA-binding motif, single-stranded-interacting protein 1 (Rbms1, mmu:56878): No pathways found
# Starch-binding domain-containing protein 1 (Stbd1, mmu:52331): No pathways found
# Putative divalent cation/proton antiporter TMEM165 (Tmem165, mmu:21982): No pathways found
# NADPH--cytochrome P450 reductase (Por): No KEGG gene ID found
# Renalase (Rnls, mmu:67795): No pathways found
# Nucleolar and coiled-body phosphoprotein 1 (Nolc1, mmu:70769): No pathways found
# Protein 4.2 (Epb42, mmu:13828): No pathways found
# Golgi integral membrane protein 4 (Golim4, mmu:73124): No pathways found
# Chitinase-like protein 3 (Chil3, mmu:12655): No pathways found
# Hemoglobin subunit beta-2 (Hbb-b2): No KEGG gene ID found
# FACT complex subunit SSRP1 (Ssrp1, mmu:20833): No pathways found
# Serine protease inhibitor A3N (Serpina3n, mmu:20716): No pathways found
# Protein FAM98B (Fam98b, mmu:68215): No pathways found
# CDK5 regulatory subunit-associated protein 3 (Cdk5rap3, mmu:80280): No pathways found
# Adenosine deaminase-like protein (Mapda): No KEGG gene ID found
# Large ribosomal subunit protein mL62 (Mrpl58, mmu:68572): No pathways found
# m-AAA protease-interacting protein 1, mitochondrial (Maip1, mmu:68115): No pathways found
# Ubiquitin-associated protein 2-like (Ubap2l, mmu:74383): No pathways found
# Insulin-like growth factor-binding protein 7 (Igfbp7, mmu:29817): No pathways found
# La-related protein 1 (Larp1, mmu:73158): No pathways found
# Spectrin alpha chain, erythrocytic 1 (Spta1, mmu:20739): No pathways found
# CLIP-associating protein 1 (Clasp1, mmu:76707): No pathways found
# 2-hydroxyacyl-CoA lyase 2 (Ilvbl, mmu:216136): No pathways found
# Serine/threonine-protein kinase Nek9 (Nek9, mmu:217718): No pathways found
# Cytoglobin (Cygb, mmu:114886): No pathways found
# A-kinase anchor protein 12 (Akap12, mmu:83397): No pathways found
# Traf2 and NCK-interacting protein kinase (Tnik, mmu:665113): No pathways found
# Protein Niban 1 (Niban1, mmu:63913): No pathways found
# Ig kappa chain V-III region PC 7210: No gene symbol found
# Procollagen C-endopeptidase enhancer 1 (Pcolce, mmu:18542): No pathways found
# Protein ABHD1 (Abhd1, mmu:57742): No pathways found
# DnaJ homolog subfamily B member 6 (Dnajb6, mmu:23950): No pathways found
# Immunoglobulin heavy constant mu (Ighm): No KEGG gene ID found
# AFG1-like ATPase (Afg1l, mmu:215951): No pathways found
# Neutrophilic granule protein (Ngp, mmu:18054): No pathways found
# Protein phosphatase 1 regulatory subunit 14B (Ppp1r14b, mmu:18938): No pathways found
# Zinc-alpha-2-glycoprotein (Azgp1, mmu:12007): No pathways found
# ADP-ribosylation factor-like protein 15 (Arl15, mmu:218639): No pathways found
# Cold-inducible RNA-binding protein (Cirbp, mmu:12696): No pathways found
# DnaJ homolog subfamily B member 5 (Dnajb5, mmu:56323): No pathways found
# Microtubule-associated protein RP/EB family member 3 (Mapre3, mmu:100732): No pathways found
# Hemopexin (Hpx, mmu:15458): No pathways found
# Protein PRRC2C (Prrc2c, mmu:226562): No pathways found
# Prothrombin (F2): No KEGG gene ID found
# Caveolae-associated protein 2 (Cavin2, mmu:20324): No pathways found
# Ubiquitin carboxyl-terminal hydrolase 19 (Usp19, mmu:71472): No pathways found
# Fetuin-B (Fetub, mmu:59083): No pathways found
# Collagen alpha-1(XII) chain (Col12a1): No KEGG gene ID found
# Apolipoprotein B-100 (Apob): No KEGG gene ID found
# OCIA domain-containing protein 1 (Ociad1): No KEGG gene ID found
# Isoform 6 of LIM domain-binding protein 3 (Ldb3): No KEGG gene ID found
# Deoxyribonuclease-1-like 1 (Dnase1l1, mmu:69537): No pathways found
# ATP synthase subunit s, mitochondrial (Dmac2l, mmu:68055): No pathways found
# Ceruloplasmin (Cp): No KEGG gene ID found
# Vitamin D-binding protein (Gc): No KEGG gene ID found
# Isoform 2B of GTPase KRas (Kras): No KEGG gene ID found
# Kininogen-1 (Kng1): No KEGG gene ID found
# Complement factor D (Cfd): No KEGG gene ID found
# Telomeric repeat-binding factor 2-interacting protein 1 (Terf2ip): No KEGG gene ID found
# Carnosine synthase 1 (Carns1): No KEGG gene ID found
# Alpha-2-antiplasmin (Serpinf2): No KEGG gene ID found
# Carboxylesterase 1C (Ces1c): No KEGG gene ID found
# Alpha-fetoprotein (Afp): No KEGG gene ID found
# Collagen alpha-6(VI) chain (Col6a6): No KEGG gene ID found
# Dynein light chain roadblock-type 1 (Dynlrb1): No KEGG gene ID found
# 1-phosphatidylinositol 4,5-bisphosphate phosphodiesterase gamma-1 (Plcg1): No KEGG gene ID found
# 1-phosphatidylinositol 4,5-bisphosphate phosphodiesterase beta-3 (Plcb3): No KEGG gene ID found
# Prefoldin subunit 2 (Pfdn2): No KEGG gene ID found
# Peptidyl-prolyl cis-trans isomerase FKBP11 (Fkbp11): No KEGG gene ID found
# Procollagen-lysine,2-oxoglutarate 5-dioxygenase 1 (Plod1): No KEGG gene ID found
# TBC1 domain family member 1 (Tbc1d1): No KEGG gene ID found
# U1 small nuclear ribonucleoprotein C (Snrpc): No KEGG gene ID found
# Neurofilament light polypeptide (Nefl): No KEGG gene ID found
# Ubiquitin recognition factor in ER-associated degradation protein 1 (Ufd1): No KEGG gene ID found
# Immunoglobulin heavy constant gamma 2B (Ighg2b): No KEGG gene ID found
# MORC family CW-type zinc finger protein 3 (Morc3): No KEGG gene ID found
# Serine protease inhibitor A3M (Serpina3m): No KEGG gene ID found
# Nebulin-related-anchoring protein (Nrap): No KEGG gene ID found
# MAGUK p55 subfamily member 3 (Mpp3): No KEGG gene ID found
# Transcription elongation factor, mitochondrial (Tefm): No KEGG gene ID found
# Prolyl 4-hydroxylase subunit alpha-1 (P4ha1): No KEGG gene ID found
# Protein MIX23 (Mix23, mmu:381045): No pathways found
# Inter-alpha-trypsin inhibitor heavy chain H3 (Itih3, mmu:16426): No pathways found
# Coatomer subunit epsilon (Cope, mmu:59042): No pathways found
# Pyruvate carboxylase, mitochondrial (Pc): No KEGG gene ID found
# Tropomodulin-3 (Tmod3): No KEGG gene ID found
# Leucine-rich repeat protein SHOC-2 (Shoc2): No KEGG gene ID found
# Ig gamma-3 chain C region: No gene symbol found
# FUN14 domain-containing protein 2 (Fundc2): No KEGG gene ID found
# Neutral alpha-glucosidase C (Ganc): No KEGG gene ID found
# Dihydropyrimidinase-related protein 3 (Dpysl3): No KEGG gene ID found
# Nuclear pore complex protein Nup155 (Nup155): No KEGG gene ID found
# Transforming acidic coiled-coil-containing protein 2 (Tacc2): No KEGG gene ID found
# Fibrinogen alpha chain (Fga): No KEGG gene ID found
# Hemoglobin subunit beta-H0 (Hbb-bh0): No KEGG gene ID found
# Keratocan (Kera): No KEGG gene ID found
# Collagen alpha-2(VI) chain (Col6a2): No KEGG gene ID found
# Structural maintenance of chromosomes protein 4 (Smc4): No KEGG gene ID found
# Ig gamma-1 chain C region, membrane-bound form (Ighg1): No KEGG gene ID found
# WASH complex subunit 5 (Washc5): No KEGG gene ID found
# Protein CDV3 (Cdv3): No KEGG gene ID found
# Drebrin (Dbn1): No KEGG gene ID found
# Coronin-1A (Coro1a): No KEGG gene ID found
# Serum paraoxonase/arylesterase 1 (Pon1): No KEGG gene ID found
# RNA-binding motif protein, X chromosome (Rbmx): No KEGG gene ID found
# Phospholipase B-like 1 (Plbd1): No KEGG gene ID found
# Serine protease HTRA2, mitochondrial (Htra2): No KEGG gene ID found
# Alpha-1-antitrypsin 1-4 (Serpina1d): No KEGG gene ID found
# Chromobox protein homolog 1 (Cbx1): No KEGG gene ID found
# Peptidyl-prolyl cis-trans isomerase FKBP10 (Fkbp10): No KEGG gene ID found
# Heat shock protein beta-7 (Hspb7): No KEGG gene ID found
# Methylmalonyl-CoA epimerase, mitochondrial (Mcee): No KEGG gene ID found
# Flavin reductase (NADPH) (Blvrb): No KEGG gene ID found
# Vesicle-associated membrane protein 3 (Vamp3): No KEGG gene ID found
# Cancer-related nucleoside-triphosphatase homolog (Ntpcr): No KEGG gene ID found
# Alpha-1-antitrypsin 1-1 (Serpina1a): No KEGG gene ID found
# Fibrinogen beta chain (Fgb): No KEGG gene ID found
# Ankyrin-1 (Ank1): No KEGG gene ID found
# Queuosine 5'-phosphate N-glycosylase/hydrolase (QNG1): No KEGG gene ID found
# Paladin (Pald1): No KEGG gene ID found
# Ubiquilin-4 (Ubqln4): No KEGG gene ID found
# Ectonucleotide pyrophosphatase/phosphodiesterase family member 3 (Enpp3): No KEGG gene ID found
# mRNA cap guanine-N7 methyltransferase (Rnmt): No KEGG gene ID found
# Cleavage stimulation factor subunit 1 (Cstf1): No KEGG gene ID found
# Collagen alpha-1(VI) chain (Col6a1): No KEGG gene ID found
# Hemoglobin subunit alpha (Hba): No KEGG gene ID found
# Pigment epithelium-derived factor (Serpinf1): No KEGG gene ID found
# Serine/threonine/tyrosine-interacting-like protein 2 (Styxl2): No KEGG gene ID found
# LIM and SH3 domain protein 1 (Lasp1): No KEGG gene ID found
# Sterol carrier protein 2 (Scp2): No KEGG gene ID found
# Inter-alpha-trypsin inhibitor heavy chain H2 (Itih2): No KEGG gene ID found
# Nuclear pore complex protein Nup98-Nup96 (Nup98): No KEGG gene ID found
# Nuclear mitotic apparatus protein 1 (Numa1): No KEGG gene ID found
# Hemoglobin subunit beta-1 (Hbb-b1): No KEGG gene ID found
# Multiple inositol polyphosphate phosphatase 1 (Minpp1): No KEGG gene ID found
# Cleavage stimulation factor subunit 2 tau variant (Cstf2t): No KEGG gene ID found
# Mitochondrial 10-formyltetrahydrofolate dehydrogenase (Aldh1l2): No KEGG gene ID found
# Integrin alpha-M (Itgam): No KEGG gene ID found
# Sorting nexin-5 (Snx5): No KEGG gene ID found
# Trem-like transcript 1 protein (Treml1): No KEGG gene ID found
# Apolipoprotein A-IV (Apoa4): No KEGG gene ID found
# Protein SON (Son): No KEGG gene ID found
# Biglycan (Bgn): No KEGG gene ID found
# Large ribosomal subunit protein P1 (Rplp1): No KEGG gene ID found
# Stefin-1 (Stfa1): No KEGG gene ID found
# Delta-1-pyrroline-5-carboxylate dehydrogenase, mitochondrial (Aldh4a1): No KEGG gene ID found
# Importin-4 (Ipo4): No KEGG gene ID found
# SEC23-interacting protein (Sec23ip): No KEGG gene ID found
# Ubiquitin-associated protein 2 (Ubap2): No KEGG gene ID found
# Calcineurin B homologous protein 1 (Chp1): No KEGG gene ID found
# Peroxiredoxin-4 (Prdx4): No KEGG gene ID found
# Rho guanine nucleotide exchange factor 7 (Arhgef7): No KEGG gene ID found
# rRNA 2'-O-methyltransferase fibrillarin (Fbl): No KEGG gene ID found
# DDB1- and CUL4-associated factor 6 (Dcaf6): No KEGG gene ID found
# Filamin-B (Flnb): No KEGG gene ID found
# Cyclin-Y (Ccny): No KEGG gene ID found
# 1-acyl-sn-glycerol-3-phosphate acyltransferase alpha (Agpat1): No KEGG gene ID found
# Alpha-2-HS-glycoprotein (Ahsg): No KEGG gene ID found
# Sorting nexin-9 (Snx9): No KEGG gene ID found
# Laminin subunit alpha-2 (Lama2): No KEGG gene ID found
# Nestin (Nes): No KEGG gene ID found
# Glia maturation factor beta (Gmfb): No KEGG gene ID found
# Transmembrane 9 superfamily member 4 (Tm9sf4): No KEGG gene ID found
# Uncharacterized protein C4orf54 homolog: No gene symbol found
# Dehydrogenase/reductase SDR family member 7B (Dhrs7b): No KEGG gene ID found
# DNA topoisomerase 2-beta (Top2b): No KEGG gene ID found
# MYG1 exonuclease (Myg1): No KEGG gene ID found
# Cation-independent mannose-6-phosphate receptor (Igf2r): No KEGG gene ID found
# Alpha-1-antitrypsin 1-2 (Serpina1b): No KEGG gene ID found
# Dehydrogenase/reductase SDR family member 11 (Dhrs11): No KEGG gene ID found
# Myoglobin (Mb): No KEGG gene ID found
# sn-1-specific diacylglycerol lipase ABHD11 (Abhd11): No KEGG gene ID found
# Regulator of nonsense transcripts 1 (Upf1): No KEGG gene ID found
# Immunoglobulin heavy constant gamma 2A (Ighg2a): No KEGG gene ID found
# Alcohol dehydrogenase 1 (Adh1): No KEGG gene ID found
# Complement C3 (C3): No KEGG gene ID found
# Apolipoprotein C-II (Apoc2): No KEGG gene ID found
# CUGBP Elav-like family member 2 (Celf2): No KEGG gene ID found
# Rho GDP-dissociation inhibitor 2 (Arhgdib): No KEGG gene ID found
# 5'-AMP-activated protein kinase subunit gamma-1 (Prkag1): No KEGG gene ID found
# Endophilin-B1 (Sh3glb1): No KEGG gene ID found
# Protein ATP1B4 (Atp1b4): No KEGG gene ID found
# SWI/SNF complex subunit SMARCC2 (Smarcc2): No KEGG gene ID found
# Isoform C of Reticulon-4 (Rtn4): No KEGG gene ID found
# Eukaryotic translation initiation factor 4 gamma 3 (Eif4g3): No KEGG gene ID found
# Ketohexokinase (Khk): No KEGG gene ID found
# Septin-4 (Septin4): No KEGG gene ID found
# Sorbitol dehydrogenase (Sord): No KEGG gene ID found
# Y-box-binding protein 1 (Ybx1): No KEGG gene ID found
# Actin-binding LIM protein 1 (Ablim1): No KEGG gene ID found
# 3-oxoacyl- reductase (Cbr4): No KEGG gene ID found
# Peroxidasin homolog (Pxdn): No KEGG gene ID found
# Sorting nexin-2 (Snx2): No KEGG gene ID found
# Profilin-2 (Pfn2): No KEGG gene ID found
# Ubiquitin-like protein ISG15 (Isg15): No KEGG gene ID found
# MOB-like protein phocein (Mob4): No KEGG gene ID found
# Inosine-5'-monophosphate dehydrogenase 2 (Impdh2): No KEGG gene ID found
# Glucosamine 6-phosphate N-acetyltransferase (Gnpnat1): No KEGG gene ID found
# Cysteine and glycine-rich protein 3 (Csrp3): No KEGG gene ID found
# Murinoglobulin-1 (Mug1): No KEGG gene ID found
# Isoform Smooth muscle of Myosin light polypeptide 6 (Myl6): No KEGG gene ID found
# Retinoid-inducible serine carboxypeptidase (Scpep1): No KEGG gene ID found
# Cysteine-rich protein 2 (Crip2): No KEGG gene ID found
# Albumin (Alb): No KEGG gene ID found
# Golgi-specific brefeldin A-resistance guanine nucleotide exchange factor 1 (Gbf1): No KEGG gene ID found
# Phosphorylase b kinase regulatory subunit beta (Phkb): No KEGG gene ID found
# Synaptic vesicle membrane protein VAT-1 homolog (Vat1): No KEGG gene ID found
# Serine--tRNA ligase, mitochondrial (Sars2): No KEGG gene ID found
# Striatin-interacting protein 1 (Strip1): No KEGG gene ID found
# AP-3 complex subunit mu-1 (Ap3m1): No KEGG gene ID found
# NADH-ubiquinone oxidoreductase chain 4 (Mtnd4): No KEGG gene ID found
# Myosin light chain 3 (Myl3): No KEGG gene ID found
# Protein FAM210A (Fam210a): No KEGG gene ID found
# Pregnancy zone protein (Pzp): No KEGG gene ID found
# NADH dehydrogenase  flavoprotein 3, mitochondrial (Ndufv3): No KEGG gene ID found
# ADP-ribosylation factor 6 (Arf6): No KEGG gene ID found
# Protein Z-dependent protease inhibitor (Serpina10): No KEGG gene ID found
# Cytoskeleton-associated protein 4 (Ckap4): No KEGG gene ID found
# Cleavage and polyadenylation specificity factor subunit 5 (Nudt21): No KEGG gene ID found
# Protein AMBP (Ambp): No KEGG gene ID found
# Vinexin (Sorbs3): No KEGG gene ID found
# Mannose-1-phosphate guanylyltransferase catalytic subunit beta (Gmppb): No KEGG gene ID found
# Phosducin-like protein 3 (Pdcl3): No KEGG gene ID found
# Supervillin (Svil): No KEGG gene ID found
# Inter alpha-trypsin inhibitor, heavy chain 4 (Itih4): No KEGG gene ID found
# Large ribosomal subunit protein uL3 (Rpl3): No KEGG gene ID found
# GTPase HRas (Hras): No KEGG gene ID found
# Putative hydrolase RBBP9 (Rbbp9): No KEGG gene ID found
# Inhibitor of carbonic anhydrase (Inhca): No KEGG gene ID found
# Far upstream element-binding protein 1 (Fubp1): No KEGG gene ID found
# Small glutamine-rich tetratricopeptide repeat-containing protein alpha (Sgta): No KEGG gene ID found
# Apolipoprotein A-II (Apoa2): No KEGG gene ID found
# Carnitine O-acetyltransferase (Crat): No KEGG gene ID found
# Unconventional myosin-Ic (Myo1c): No KEGG gene ID found
# Transmembrane anterior posterior transformation protein 1 (Tapt1): No KEGG gene ID found
# Carboxymethylenebutenolidase homolog (Cmbl): No KEGG gene ID found
# Collagen alpha-1(XIV) chain (Col14a1): No KEGG gene ID found
# AP-2 complex subunit alpha-2 (Ap2a2): No KEGG gene ID found
# Medium-chain acyl-CoA ligase ACSF2, mitochondrial (Acsf2): No KEGG gene ID found
# Angiotensinogen (Agt): No KEGG gene ID found
# Superoxide dismutase (Sod1): No KEGG gene ID found
# Phosphatidylinositol 3,4,5-trisphosphate 5-phosphatase 2 (Inppl1): No KEGG gene ID found
# Laminin subunit beta-1 (Lamb1): No KEGG gene ID found
# Serotransferrin (Tf): No KEGG gene ID found
# Interleukin enhancer-binding factor 3 (Ilf3): No KEGG gene ID found
# Carbonic anhydrase 3 (Ca3): No KEGG gene ID found
# Peptidyl-prolyl cis-trans isomerase H (Ppih): No KEGG gene ID found
# Coiled-coil domain-containing protein 134 (Ccdc134): No KEGG gene ID found
# Laminin subunit alpha-4 (Lama4): No KEGG gene ID found
# Insulin-like growth factor II (Igf2): No KEGG gene ID found
# PCI domain-containing protein 2 (Pcid2): No KEGG gene ID found
# Aldehyde dehydrogenase family 3 member A2 (Aldh3a2): No KEGG gene ID found
# Kinesin-like protein KIF1B (Kif1b): No KEGG gene ID found
# Twinfilin-1 (Twf1): No KEGG gene ID found
# Sodium channel protein type 4 subunit alpha (Scn4a): No KEGG gene ID found
# Peroxisomal multifunctional enzyme type 2 (Hsd17b4): No KEGG gene ID found
# Heat shock 70 kDa protein 12B (Hspa12b): No KEGG gene ID found
# Extended synaptotagmin-1 (Esyt1): No KEGG gene ID found
# Core histone macro-H2A.2 (Macroh2a2): No KEGG gene ID found
# Reticulocalbin-3 (Rcn3): No KEGG gene ID found
#
# Saved full mouse analysis to 2. 95p_Original_35277_LFQ_PD_WT_vs_Ts65Dn_P14.xlsx!

# %%
import pandas as pd
import requests
import time

# input file information
input_file = "2. 95p_Original_35277_LFQ_PD_WT_vs_Ts65Dn_P14.xlsx"
sheet_name = "Pathway Summary P14"
# load the sheet containing pathways
df = pd.read_excel(input_file, sheet_name=sheet_name)
# new columns to fill
categories = []
subcategories = []
def get_kegg_class(pathway_id):
    """Return (category, subcategory) from KEGG CLASS field."""
    url = f"http://rest.kegg.jp/get/{pathway_id}"
    r = requests.get(url)
    if r.status_code != 200:
        return None, None
    category = None
    subcategory = None
    for line in r.text.splitlines():
        if line.startswith("CLASS"):
            # Remove "CLASS" and split the remaining text
            class_text = line.replace("CLASS", "").strip()
            if ";" in class_text:
                parts = [x.strip() for x in class_text.split(";")]
                if len(parts) >= 2:
                    category = parts[0]
                    subcategory = parts[1]
                else:
                    # only one piece found
                    category = parts[0]
                    subcategory = None
            else:
                category = class_text
                subcategory = None
            break
    return category, subcategory

# process each pathway ID
for pid in df["Pathway ID"]:
    cat, subcat = get_kegg_class(pid)
    categories.append(cat)
    subcategories.append(subcat)
    time.sleep(0.2)  # KEGG rate limit safety
# add new columns
df["Category"] = categories
df["Subcategory"] = subcategories

# save output
output_file = "3. 95p_Original_35277_LFQ_PD_WT_vs_Ts65Dn_P14.xlsx"
df.to_excel(output_file, index=False)
print(f"\nSaved pathway classes to: {output_file}")
# Out:
# Saved pathway classes to: 3. 95p_Original_35277_LFQ_PD_WT_vs_Ts65Dn_P14.xlsx
